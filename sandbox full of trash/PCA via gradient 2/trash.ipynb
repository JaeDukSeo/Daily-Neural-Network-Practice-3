# %%
from sklearn.decomposition import PCA, KernelPCA
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
X, y = make_circles(n_samples=30, factor=.001, noise=.0)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
temp =np.argsort(y)
print(temp)
xxx = X[temp]

plt.scatter(xxx[:15,0],xxx[:15,1])
plt.show()

plt.scatter(xxx[14:,0],xxx[14:,1])
plt.show()
# Out:
# [ 0 26 25 23 22 19 17 15 12 14  5  1  7  3  6 27  2 24  4 21 10  9 18 16
#  28 13  8 11 20 29]

# %%
import seaborn as sns; sns.set()
corr = np.corrcoef(xxx)
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(np.corrcoef(xxx[:15]))
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(np.corrcoef(xxx[15:]))
plt.show()
